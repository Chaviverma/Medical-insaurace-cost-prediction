# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Health_Insurance.xlsm', engine='openpyxl')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(4)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061

# %%
df.tail(4)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# there is no missing value
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
print("Average age",df['age'].mean().round(2))
print("Average bmi" ,df['bmi'].mean().round(2))
# Out:
# Average age 39.21
# Average bmi 30.66

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid", palette="muted", font_scale=1.1)

# Numerical columns
num_cols = ["age", "bmi", "children", "charges"]

# Plot distributions for numerical features
for col in num_cols:
    plt.figure(figsize=(8,4))
    sns.histplot(df[col], kde=True, bins=30, color="skyblue")
    plt.title(f"Distribution of {col}", fontsize=14)
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# Boxplots for outlier detection
for col in num_cols:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[col], color="lightcoral")
    plt.title(f"Boxplot of {col}", fontsize=14)
    plt.show()

# Categorical columns
cat_cols = ["sex", "smoker", "region"]

# Count plots for categorical features
for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=df[col], palette="pastel")
    plt.title(f"Count of {col}", fontsize=14)
    plt.ylabel("Count")
    plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7404\2872089658.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette="pastel")
# C:\Users\HP\AppData\Local\Temp\ipykernel_7404\2872089658.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette="pastel")
# C:\Users\HP\AppData\Local\Temp\ipykernel_7404\2872089658.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[col], palette="pastel")

# %% [raw]
# # insights from above visualization
#
# Age: Customers range from 18 to 64 years, roughly uniformly spread, with median ~39.
#
# BMI: Centered around 30–31, slightly right-skewed. Some extreme outliers (>40) suggest obesity.
#
# Children: Most customers have 0–2 children, few have more than 4.
#
# Charges: Very right-skewed, most people pay below 20k, but a few pay up to 64k (outliers).
#
# Categorical variables:
#
# Sex: Almost balanced (676 male, 662 female).
#
# Smoker: Imbalanced — 80% non-smokers, 20% smokers.
#
# Region: All 4 regions present, fairly balanced; Southeast is slightly more freque

# %%
# Scatter plots for numerical vs numerical
plt.figure(figsize=(8,5))
sns.scatterplot(x="age", y="charges", hue="smoker", data=df, palette="coolwarm", alpha=0.7)
plt.title("Age vs Charges (Colored by Smoker)")
plt.show()

plt.figure(figsize=(8,5))
sns.scatterplot(x="bmi", y="charges", hue="smoker", data=df, palette="Set1", alpha=0.7)
plt.title("BMI vs Charges (Colored by Smoker)")
plt.show()

# Boxplots for categorical vs numerical
plt.figure(figsize=(6,4))
sns.boxplot(x="sex", y="charges", data=df, palette="pastel")
plt.title("Charges by Sex")
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x="smoker", y="charges", data=df, palette="muted")
plt.title("Charges by Smoker Status")
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x="region", y="charges", data=df, palette="Set2")
plt.title("Charges by Region")
plt.show()

# Heatmap for correlation among numerical variables
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7404\308090981.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="sex", y="charges", data=df, palette="pastel")
# C:\Users\HP\AppData\Local\Temp\ipykernel_7404\308090981.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="smoker", y="charges", data=df, palette="muted")
# C:\Users\HP\AppData\Local\Temp\ipykernel_7404\308090981.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="region", y="charges", data=df, palette="Set2")

# %% [raw]
# # insights from above visualizatrion
#
# Smokers vs Charges: Smokers have much higher charges compared to non-smokers (clear separation).
#
# BMI vs Charges: Charges rise with BMI, especially for smokers. Obese smokers have the highest medical bills.
#
# Age vs Charges: Older people tend to pay more, particularly if they are smokers.
#
# Children vs Charges: Having children doesn’t strongly affect charges.
#
# Region vs Charges: Charges don’t vary significantly across regions.

# %%
# checking for outliers
import matplotlib.pyplot as plt
import seaborn as sns

# Numerical columns
num_cols = ["age", "bmi", "children", "charges"]

# Boxplots for each numerical column
for col in num_cols:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[col], color="lightcoral")
    plt.title(f"Boxplot of {col}", fontsize=14)
    plt.show()

# --- Using IQR method ---
outliers = {}
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers[col] = df[(df[col] < lower_bound) | (df[col] > upper_bound)].shape[0]

print("Number of outliers detected using IQR method:")
for k, v in outliers.items():
    print(f"{k}: {v}")
# Out:
# Number of outliers detected using IQR method:
# age: 0
# bmi: 9
# children: 0
# charges: 139

# %%
# treating outliers
#Treat Outliers 
for col in ["bmi", "charges"]:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    # Cap the outliers instead of removing
    df[col] = np.where(df[col] < lower, lower,
                       np.where(df[col] > upper, upper, df[col]))

print("\n Outliers treated (capped using IQR method).")
# Out:
#  Outliers treated (capped using IQR method).

# %%
# Encode binary categorical variables
df['sex'] = df['sex'].map({'male': 1, 'female': 0})
df['smoker'] = df['smoker'].map({'yes': 1, 'no': 0})

# One-hot encoding for region
df = pd.get_dummies(df, columns=['region'], drop_first=True)

# %%
df
# Out:
#       age  sex     bmi  children  smoker      charges  region_northwest  \
# 0      19    0  27.900         0       1  16884.92400             False
# 1      18    1  33.770         1       0   1725.55230             False
# 2      28    1  33.000         3       0   4449.46200             False
# 3      33    1  22.705         0       0  21984.47061              True
# 4      32    1  28.880         0       0   3866.85520              True
# ...   ...  ...     ...       ...     ...          ...               ...
# 1333   50    1  30.970         3       0  10600.54830              True
# 1334   18    0  31.920         0       0   2205.98080             False
# 1335   18    0  36.850         0       0   1629.83350             False
# 1336   21    0  25.800         0       0   2007.94500             False
# 1337   61    0  29.070         0       1  29141.36030              True
#
#       region_southeast  region_southwest
# 0                False              True
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical columns
num_cols = ["age", "bmi", "children", "charges"]

scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df
# Out:
#            age  sex       bmi  children  smoker   charges  region_northwest  \
# 0     0.021739    0  0.381104       0.0       1  0.472408             False
# 1     0.000000    1  0.568465       0.2       0  0.018092             False
# 2     0.217391    1  0.543888       0.6       0  0.099725             False
# 3     0.326087    1  0.215289       0.0       0  0.625237              True
# 4     0.304348    1  0.412384       0.0       0  0.082265              True
# ...        ...  ...       ...       ...     ...       ...               ...
# 1333  0.695652    1  0.479094       0.6       0  0.284069              True
# 1334  0.000000    0  0.509416       0.0       0  0.032490             False
# 1335  0.000000    0  0.666773       0.0       0  0.015223             False
# 1336  0.065217    0  0.314076       0.0       0  0.026555             False
# 1337  0.934783    0  0.418449       0.0       1  0.839724              True
#
#       region_southeast  region_southwest
# ...

# %%
# Check skewness
print(df[["age", "bmi", "children", "charges"]].skew())
# Out:
# age         0.055673
# bmi         0.232507
# children    0.938380
# charges     1.083730
# dtype: float64

# %%
df["charges_log"] = np.log1p(df["charges"])  # log(1+x) to handle 0 values

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method='yeo-johnson')
df["charges_yeojohnson"] = pt.fit_transform(df[["charges"]])

print("Lambdas used:", pt.lambdas_)
# Out:
# Lambdas used: [-2.20761437]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.histplot(df["charges"], kde=True, color="red")
plt.title("Original Charges")

plt.subplot(1,2,2)
sns.histplot(df["charges_log"], kde=True, color="green")
plt.title("Log Transformed Charges")
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Features & Target
X = df.drop(columns=['charges'])
y = df['charges']

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "SVR": SVR(kernel="rbf"),
    "KNN": KNeighborsRegressor(n_neighbors=5),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=100, random_state=42),
    "AdaBoost": AdaBoostRegressor(n_estimators=100, random_state=42)
}

results = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    results[name] = {"RMSE": rmse, "R2 Score": r2}

# Convert results to DataFrame
results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#                        RMSE  R2 Score
# Linear Regression  0.004680  0.999775
# Decision Tree      0.001824  0.999966
# Random Forest      0.001426  0.999979
# SVR                0.063302  0.958902
# KNN                0.066586  0.954527
# Gradient Boosting  0.002180  0.999951
# AdaBoost           0.016900  0.997071

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def adjusted_r2(r2, n, k):
    """Calculate Adjusted R² Score"""
    return 1 - ((1 - r2) * (n - 1)) / (n - k - 1)

# Store results
eval_results = {}

for name, model in models.items():
    # Predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Train metrics
    train_mae = mean_absolute_error(y_train, y_train_pred)
    train_mse = mean_squared_error(y_train, y_train_pred)
    train_rmse = np.sqrt(train_mse)
    train_r2 = r2_score(y_train, y_train_pred)
    train_adj_r2 = adjusted_r2(train_r2, X_train.shape[0], X_train.shape[1])

    # Test metrics
    test_mae = mean_absolute_error(y_test, y_test_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)
    test_rmse = np.sqrt(test_mse)
    test_r2 = r2_score(y_test, y_test_pred)
    test_adj_r2 = adjusted_r2(test_r2, X_test.shape[0], X_test.shape[1])

    # Save results
    eval_results[name] = {
        "Train_MAE": train_mae, "Test_MAE": test_mae,
        "Train_MSE": train_mse, "Test_MSE": test_mse,
        "Train_RMSE": train_rmse, "Test_RMSE": test_rmse,
        "Train_R2": train_r2, "Test_R2": test_r2,
        "Train_Adj_R2": train_adj_r2, "Test_Adj_R2": test_adj_r2
    }

# Convert to DataFrame for comparison
eval_df = pd.DataFrame(eval_results).T
print(eval_df)
# Out:
#                    Train_MAE  Test_MAE     Train_MSE  Test_MSE  Train_RMSE  \
# Linear Regression   0.003937  0.003934  2.230196e-05  0.000022    0.004722
# Decision Tree       0.000000  0.000731  0.000000e+00  0.000003    0.000000
# Random Forest       0.000202  0.000587  2.016260e-07  0.000002    0.000449
# SVR                 0.052711  0.052014  3.773011e-03  0.004007    0.061425
# KNN                 0.024840  0.034641  2.153060e-03  0.004434    0.046401
# Gradient Boosting   0.001012  0.001452  2.162864e-06  0.000005    0.001471
# AdaBoost            0.013678  0.014361  2.652409e-04  0.000286    0.016286
#
#                    Test_RMSE  Train_R2   Test_R2  Train_Adj_R2  Test_Adj_R2
# Linear Regression   0.004680  0.999756  0.999775      0.999754     0.999767
# Decision Tree       0.001824  1.000000  0.999966      1.000000     0.999965
# Random Forest       0.001426  0.999998  0.999979      0.999998     0.999978
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to plot stacked bar chart
def plot_stacked(metric_train, metric_test, metric_name):
    models = eval_df.index
    train_vals = eval_df[metric_train]
    test_vals = eval_df[metric_test]

    bar_width = 0.6
    x = np.arange(len(models))

    plt.figure(figsize=(10,6))
    plt.bar(x, train_vals, color="skyblue", label=f"Train {metric_name}", width=bar_width)
    plt.bar(x, test_vals, bottom=train_vals, color="orange", label=f"Test {metric_name}", width=bar_width)

    plt.xticks(x, models, rotation=45)
    plt.ylabel(metric_name)
    plt.title(f"Train vs Test {metric_name} (Stacked Bar)")
    plt.legend()
    plt.show()

# Plot for R²
plot_stacked("Train_R2", "Test_R2", "R² Score")

# Plot for RMSE
plot_stacked("Train_RMSE", "Test_RMSE", "RMSE")

# %%
from sklearn.model_selection import RandomizedSearchCV
# Random Forest 
rf = RandomForestRegressor(random_state=42)

param_dist_rf = {
    "n_estimators": [100, 200],
    "max_depth": [None, 5, 10],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2]
}

rand_rf = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist_rf,
    n_iter=5,          # only 5 random combos (fast)
    cv=3,              # 3-fold cross validation
    n_jobs=-1,
    scoring="r2",
    random_state=42
)
rand_rf.fit(X_train, y_train)
print("Best RF Params:", rand_rf.best_params_)
print("Best RF CV Score:", rand_rf.best_score_)
# Evaluate on test set
rf_best = rand_rf.best_estimator_
print("Random Forest Test R2:", r2_score(y_test, rf_best.predict(X_test)))
# Out:
# Best RF Params: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': None}
# Best RF CV Score: 0.9999666065867405
# Random Forest Test R2: 0.9999791341815876

# %%
# Gradient Boosting (Fast Tuning)
gb = GradientBoostingRegressor(random_state=42)
param_dist_gb = {
    "n_estimators": [100, 200],
    "learning_rate": [0.05, 0.1],
    "max_depth": [3, 4],
    "min_samples_split": [2, 5]
}

rand_gb = RandomizedSearchCV(
    estimator=gb,
    param_distributions=param_dist_gb,
    n_iter=5,          # only 5 random combos
    cv=3,
    n_jobs=-1,
    scoring="r2",
    random_state=42
)

rand_gb.fit(X_train, y_train)
print(" Best GB Params:", rand_gb.best_params_)
print("Best GB CV Score:", rand_gb.best_score_)
# Evaluate on test set
gb_best = rand_gb.best_estimator_
print("Gradient Boosting Test R2:", r2_score(y_test, gb_best.predict(X_test)))
# Out:
#  Best GB Params: {'n_estimators': 200, 'min_samples_split': 2, 'max_depth': 4, 'learning_rate': 0.05}
# Best GB CV Score: 0.9999608357905228
# Gradient Boosting Test R2: 0.999988915745586

# %%
# Build comparison table
comparison_df = eval_df[["Train_RMSE", "Test_RMSE", "Train_R2", "Test_R2"]].copy()

# Round values for readability
comparison_df = comparison_df.round(2)

# Add Overfitting flag
comparison_df["Overfitting (Y/N)"] = np.where(
    (comparison_df["Train_R2"] - comparison_df["Test_R2"]) > 0.1, "Y", "N"
)

# Identify best model (highest Test R²)
best_model = comparison_df["Test_R2"].idxmax()

# Add Best Model row
best_row = pd.DataFrame(
    [["-", "-", "-", "-", "-", best_model]],
    columns=["Train RMSE", "Test RMSE", "Train R²", "Test R²", "Overfitting (Y/N)", "Best Model"],
    index=["Best Model"]
)

# Rename columns to match required format
comparison_df = comparison_df.rename(columns={
    "Train_RMSE": "Train RMSE",
    "Test_RMSE": "Test RMSE",
    "Train_R2": "Train R²",
    "Test_R2": "Test R²"
})

# Add empty "Best Model" column for consistency
comparison_df["Best Model"] = "-"

# Concatenate final table
final_table = pd.concat([comparison_df, best_row])

comparison_table=pd.DataFrame(final_table)
comparison_table
# Out:
#                   Train RMSE Test RMSE Train R² Test R² Overfitting (Y/N)  \
# Linear Regression        0.0       0.0      1.0     1.0                 N
# Decision Tree            0.0       0.0      1.0     1.0                 N
# Random Forest            0.0       0.0      1.0     1.0                 N
# SVR                     0.06      0.06     0.96    0.96                 N
# KNN                     0.05      0.07     0.98    0.95                 N
# Gradient Boosting        0.0       0.0      1.0     1.0                 N
# AdaBoost                0.02      0.02      1.0     1.0                 N
# Best Model                 -         -        -       -                 -
#
#                           Best Model
# Linear Regression                  -
# Decision Tree                      -
# Random Forest                      -
# SVR                                -
# KNN                                -
# Gradient Boosting                  -
# ...
